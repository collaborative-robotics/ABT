# %%
import nltk
import numpy as np
from sklearn.preprocessing import normalize
from nltk.corpus import genesis as gen
from nltk import pos_tag
np.random.seed(10000)

# %%
word_corpus = {}
word_corpus_rev = {}
num = 0
for word in (nltk.corpus.genesis.words()):
    if word not in word_corpus and word.isalpha():
        word_corpus_rev[num] = word
        word_corpus[word] = num
        num += 1

# %%
states = ['CC','CD','DT','EX','FW','IN','JJ','JJR','JJS','LS','MD','NN','NNS','NNP','NNPS','PDT','POS','PRP','PRP','RB','RBR','RBS','RP','TO','UH',"VB",'VBD','VBG','VBN','VBP','VBZ','WDT','WP','WP','WRB']
transition = normalize(np.random.random((len(states),len(states))), norm='l1')
emission = normalize(np.random.random((len(word_corpus),len(states))), norm = 'l1')
initial = normalize(np.random.random((len(states),1)), norm = 'l1')

# %%
transitionc = {}
for i,condition in enumerate(states):
    dic = {}
    for j,state in enumerate(states):
        dic[state] = transition[i][j]
    transitionc[condition] = ( nltk.probability.DictionaryProbDist(dic))
transitionc = nltk.probability.DictionaryConditionalProbDist(transitionc);

emissionc = {}
for i,condition in enumerate(list(word_corpus)):
    dic = {}
    for j,state in enumerate(states):
        dic[state] = emission[i][j]
    emissionc[condition] = ( nltk.probability.DictionaryProbDist(dic))
emissionc = nltk.probability.DictionaryConditionalProbDist(transitionc);

initialc = {}
for i,condition in enumerate(states):
    initialc[condition] = initial[i]
initialc = nltk.probability.DictionaryProbDist(initialc)

# %%
model = nltk.tag.hmm.HiddenMarkovModelTagger(list(word_corpus),states,transitionc,emissionc,initialc)

# %%
# a = nltk.pos_tag(nltk.corpus.genesis.sents())
obs_nltk = []
obs_blake = []
lens = []
for sentence in gen.sents():
    sen = []
    for word in sentence:
        if word.isalpha():
            sen.append((word,pos_tag([word])[0][1]))
            obs_blake.append(word_corpus[word])
    lens.append(len(sen))
    obs_nltk.append(sen)

# %%
print(len(set(obs_blake)),len(set(word_corpus)))
print((set(obs_blake) ^ set(word_corpus)))
word_corpus
# Out:
# 25513 25513
# set()
# {'In': 0,
#  'the': 1,
#  'beginning': 2,
#  'God': 3,
#  'created': 4,
#  'heaven': 5,
#  'and': 6,
#  'earth': 7,
#  'And': 8,
#  'was': 9,
#  'without': 10,
#  'form': 11,
#  'void': 12,
#  'darkness': 13,
#  'upon': 14,
#  'face': 15,
#  'of': 16,
#  'deep': 17,
#  'Spirit': 18,
#  'moved': 19,
#  'waters': 20,
#  'said': 21,
#  'Let': 22,
#  'there': 23,
#  'be': 24,
#  'light': 25,
#  'saw': 26,
#  'that': 27,
#  'it': 28,
#  'good': 29,
#  'divided': 30,
#  'from': 31,
#  'called': 32,
#  'Day': 33,
#  'he': 34,
#  'Night': 35,
#  'evening': 36,
#  'morning': 37,
#  'were': 38,
#  'first': 39,
#  'day': 40,
#  'a': 41,
#  'firmament': 42,
#  'in': 43,
#  'midst': 44,
#  'let': 45,
#  'divide': 46,
#  'made': 47,
#  'which': 48,
#  'under': 49,
#  'above': 50,
#  'firmame': 51,
#  'so': 52,
#  'Heaven': 53,
#  'second': 54,
#  'gathered': 55,
#  'together': 56,
#  'unto': 57,
#  'one': 58,
#  'place': 59,
#  'dry': 60,
#  'land': 61,
#  'appe': 62,
#  'Earth': 63,
#  'gathering': 64,
#  'Se': 65,
#  'bring': 66,
#  'forth': 67,
#  'grass': 68,
#  'herb': 69,
#  'yielding': 70,
#  'seed': 71,
#  'fruit': 72,
#  'tree': 73,
#  'after': 74,
#  'his': 75,
#  'kind': 76,
#  'whose': 77,
#  'is': 78,
#  'itself': 79,
#  'ear': 80,
#  'brought': 81,
#  'ki': 82,
#  'third': 83,
#  'lights': 84,
#  'to': 85,
#  'night': 86,
#  'them': 87,
#  'for': 88,
#  'signs': 89,
#  'seasons': 90,
#  'days': 91,
#  'yea': 92,
#  'give': 93,
#  'two': 94,
#  'great': 95,
#  'greater': 96,
#  'rule': 97,
#  'lesser': 98,
#  'nig': 99,
#  'stars': 100,
#  'also': 101,
#  'set': 102,
#  'over': 103,
#  'darkne': 104,
#  'fourth': 105,
#  'abundantly': 106,
#  'moving': 107,
#  'creature': 108,
#  'hath': 109,
#  'life': 110,
#  'fowl': 111,
#  'may': 112,
#  'fly': 113,
#  'open': 114,
#  'whales': 115,
#  'every': 116,
#  'living': 117,
#  'moveth': 118,
#  'their': 119,
#  'winged': 120,
#  'blessed': 121,
#  'saying': 122,
#  'Be': 123,
#  'fruitful': 124,
#  'multiply': 125,
#  'fill': 126,
#  'seas': 127,
#  'fifth': 128,
#  'cattle': 129,
#  'creeping': 130,
#  'thing': 131,
#  'beast': 132,
#  'creepeth': 133,
#  'us': 134,
#  'make': 135,
#  'man': 136,
#  'our': 137,
#  'image': 138,
#  'likene': 139,
#  'have': 140,
#  'dominion': 141,
#  'fish': 142,
#  'sea': 143,
#  'air': 144,
#  'all': 145,
#  'So': 146,
#  'own': 147,
#  'him': 148,
#  'male': 149,
#  'female': 150,
#  'replenish': 151,
#  'subdue': 152,
#  'Behold': 153,
#  'I': 154,
#  'given': 155,
#  'you': 156,
#  'bearing': 157,
#  'shall': 158,
#  'meat': 159,
#  'wherein': 160,
#  'green': 161,
#  'me': 162,
#  'had': 163,
#  'behold': 164,
#  'very': 165,
#  'sixth': 166,
#  'Thus': 167,
#  'heavens': 168,
#  'finished': 169,
#  'host': 170,
#  'on': 171,
#  'seventh': 172,
#  'ended': 173,
#  'work': 174,
#  'rested': 175,
#  'sanctified': 176,
#  'because': 177,
#  'These': 178,
#  'are': 179,
#  'generations': 180,
#  'when': 181,
#  'they': 182,
#  'LORD': 183,
#  'plant': 184,
#  'field': 185,
#  'before': 186,
#  'gr': 187,
#  'not': 188,
#  'caused': 189,
#  'rain': 190,
#  'till': 191,
#  'ground': 192,
#  'But': 193,
#  'went': 194,
#  'up': 195,
#  'mist': 196,
#  'watered': 197,
#  'whole': 198,
#  'formed': 199,
#  'dust': 200,
#  'breathed': 201,
#  'into': 202,
#  'nostrils': 203,
#  'breath': 204,
#  'became': 205,
#  'soul': 206,
#  'planted': 207,
#  'garden': 208,
#  'eastward': 209,
#  'Eden': 210,
#  'put': 211,
#  'whom': 212,
#  'out': 213,
#  'grow': 214,
#  'pleasant': 215,
#  'sight': 216,
#  'food': 217,
#  'knowledge': 218,
#  'evil': 219,
#  'river': 220,
#  'water': 221,
#  'thence': 222,
#  'parted': 223,
#  'four': 224,
#  'heads': 225,
#  'The': 226,
#  'name': 227,
#  'Pison': 228,
#  'compasseth': 229,
#  'Havilah': 230,
#  'where': 231,
#  'gold': 232,
#  'bdellium': 233,
#  'onyx': 234,
#  'stone': 235,
#  'Gihon': 236,
#  'same': 237,
#  'Ethiopia': 238,
#  'Hiddekel': 239,
#  'goeth': 240,
#  'toward': 241,
#  'east': 242,
#  'Assyria': 243,
#  'Euphrates': 244,
#  'took': 245,
#  'dress': 246,
#  'keep': 247,
#  'commanded': 248,
#  'Of': 249,
#  'thou': 250,
#  'mayest': 251,
#  'freely': 252,
#  'e': 253,
#  'shalt': 254,
#  'eat': 255,
#  'eatest': 256,
#  'thereof': 257,
#  'surely': 258,
#  'die': 259,
#  'It': 260,
#  'should': 261,
#  'alone': 262,
#  'will': 263,
#  'an': 264,
#  'help': 265,
#  'meet': 266,
#  'Adam': 267,
#  'see': 268,
#  'what': 269,
#  'would': 270,
#  'call': 271,
#  'th': 272,
#  'whatsoever': 273,
#  'gave': 274,
#  'names': 275,
#  'but': 276,
#  'found': 277,
#  'sleep': 278,
#  'fall': 279,
#  'sle': 280,
#  'ribs': 281,
#  'closed': 282,
#  'flesh': 283,
#  'instead': 284,
#  'rib': 285,
#  'taken': 286,
#  'woman': 287,
#  'her': 288,
#  'This': 289,
#  'now': 290,
#  'bone': 291,
#  'my': 292,
#  'bones': 293,
#  'fle': 294,
#  'she': 295,
#  'Woman': 296,
#  'Man': 297,
#  'Therefore': 298,
#  'leave': 299,
#  'father': 300,
#  'mother': 301,
#  'cleave': 302,
#  'wife': 303,
#  'both': 304,
#  'naked': 305,
#  'ashamed': 306,
#  'Now': 307,
#  'serpent': 308,
#  'more': 309,
#  'subtil': 310,
#  'than': 311,
#  'any': 312,
#  'Yea': 313,
#  'Ye': 314,
#  'We': 315,
#  'trees': 316,
#  'gard': 317,
#  'neither': 318,
#  'ye': 319,
#  'touch': 320,
#  'lest': 321,
#  'For': 322,
#  'doth': 323,
#  'know': 324,
#  'then': 325,
#  'your': 326,
#  'eyes': 327,
#  'opened': 328,
#  'as': 329,
#  'gods': 330,
#  'knowing': 331,
#  'desired': 332,
#  'wise': 333,
#  'did': 334,
#  'husband': 335,
#  'with': 336,
#  'knew': 337,
#  'sewed': 338,
#  'fig': 339,
#  'leaves': 340,
#  'themselves': 341,
#  'aprons': 342,
#  'heard': 343,
#  'voice': 344,
#  'walking': 345,
#  'cool': 346,
#  'd': 347,
#  'hid': 348,
#  'presence': 349,
#  'amongst': 350,
#  'Where': 351,
#  'art': 352,
#  'thy': 353,
#  'afraid': 354,
#  'myself': 355,
#  'Who': 356,
#  'told': 357,
#  'thee': 358,
#  'wast': 359,
#  'Hast': 360,
#  'eaten': 361,
#  'whereof': 362,
#  'shouldest': 363,
#  'gavest': 364,
#  'What': 365,
#  'this': 366,
#  'hast': 367,
#  'done': 368,
#  'beguiled': 369,
#  'Because': 370,
#  'cursed': 371,
#  'belly': 372,
#  'go': 373,
#  'li': 374,
#  'enmity': 375,
#  'between': 376,
#  'bruise': 377,
#  'head': 378,
#  'heel': 379,
#  'Unto': 380,
#  'greatly': 381,
#  'sorrow': 382,
#  'conception': 383,
#  'children': 384,
#  'desire': 385,
#  'hearkened': 386,
#  'Thou': 387,
#  'sake': 388,
#  'Thorns': 389,
#  'thistles': 390,
#  'sweat': 391,
#  'bread': 392,
#  'return': 393,
#  'tak': 394,
#  's': 395,
#  'Eve': 396,
#  'coats': 397,
#  'skins': 398,
#  'clothed': 399,
#  'become': 400,
#  'ev': 401,
#  'hand': 402,
#  'take': 403,
#  'live': 404,
#  'sent': 405,
#  'whence': 406,
#  'drove': 407,
#  'placed': 408,
#  'at': 409,
#  'Cherubims': 410,
#  'flaming': 411,
#  'sword': 412,
#  'turned': 413,
#  'way': 414,
#  'conceived': 415,
#  'bare': 416,
#  'Cain': 417,
#  'gotten': 418,
#  'again': 419,
#  'brother': 420,
#  'Abel': 421,
#  'keeper': 422,
#  'sheep': 423,
#  'tiller': 424,
#  'process': 425,
#  'time': 426,
#  'came': 427,
#  'pass': 428,
#  'offering': 429,
#  'firstlings': 430,
#  'flock': 431,
#  'fat': 432,
#  'respect': 433,
#  'offeri': 434,
#  'wroth': 435,
#  'countenance': 436,
#  'fell': 437,
#  'Why': 438,
#  'why': 439,
#  'fallen': 440,
#  'If': 441,
#  'doest': 442,
#  'well': 443,
#  'accepted': 444,
#  'if': 445,
#  'sin': 446,
#  'lieth': 447,
#  'door': 448,
#  'talked': 449,
#  'rose': 450,
#  'against': 451,
#  'slew': 452,
#  'n': 453,
#  'Am': 454,
#  'blood': 455,
#  'crieth': 456,
#  'mouth': 457,
#  'receive': 458,
#  'When': 459,
#  'tillest': 460,
#  'henceforth': 461,
#  'yield': 462,
#  'strength': 463,
#  'fugitive': 464,
#  'vagabond': 465,
#  'My': 466,
#  'punishment': 467,
#  'can': 468,
#  'bear': 469,
#  'driven': 470,
#  'come': 471,
#  'findeth': 472,
#  'slay': 473,
#  'whosoever': 474,
#  'slayeth': 475,
#  'vengeance': 476,
#  'sevenfold': 477,
#  'mark': 478,
#  'finding': 479,
#  'kill': 480,
#  'dwelt': 481,
#  'Nod': 482,
#  'Enoch': 483,
#  'builded': 484,
#  'city': 485,
#  'son': 486,
#  'born': 487,
#  'Irad': 488,
#  'begat': 489,
#  'Mehujael': 490,
#  'Methusa': 491,
#  'Methusael': 492,
#  'Lamech': 493,
#  'wives': 494,
#  'Adah': 495,
#  'other': 496,
#  'Zillah': 497,
#  'Jabal': 498,
#  'such': 499,
#  'dwell': 500,
#  'tents': 501,
#  'Jubal': 502,
#  'handle': 503,
#  'harp': 504,
#  'organ': 505,
#  'Tubalcain': 506,
#  'instructor': 507,
#  'artificer': 508,
#  'brass': 509,
#  'ir': 510,
#  'sister': 511,
#  'Naamah': 512,
#  'Hear': 513,
#  'hearken': 514,
#  'spee': 515,
#  'slain': 516,
#  'wounding': 517,
#  'young': 518,
#  'hurt': 519,
#  'avenged': 520,
#  'truly': 521,
#  'seventy': 522,
#  'appointed': 523,
#  'another': 524,
#  'Seth': 525,
#  'En': 526,
#  'began': 527,
#  'men': 528,
#  'book': 529,
#  'likeness': 530,
#  'Male': 531,
#  'lived': 532,
#  'hundred': 533,
#  'thirty': 534,
#  'years': 535,
#  'begotten': 536,
#  'eight': 537,
#  'sons': 538,
#  'daughters': 539,
#  'nine': 540,
#  'died': 541,
#  'five': 542,
#  'Enos': 543,
#  'seven': 544,
#  'daughte': 545,
#  'twelve': 546,
#  'ninety': 547,
#  'Cainan': 548,
#  'fifteen': 549,
#  'Mahalaleel': 550,
#  'forty': 551,
#  'ten': 552,
#  'sixty': 553,
#  'Jared': 554,
#  'Eno': 555,
#  'Methuselah': 556,
#  'walked': 557,
#  'three': 558,
#  'eighty': 559,
#  'Noah': 560,
#  'comfort': 561,
#  'concerning': 562,
#  'toil': 563,
#  'hands': 564,
#  'old': 565,
#  'Shem': 566,
#  'Ham': 567,
#  'Japheth': 568,
#  'That': 569,
#  'fair': 570,
#  'chose': 571,
#  'spirit': 572,
#  'always': 573,
#  'strive': 574,
#  'yet': 575,
#  'twenty': 576,
#  'There': 577,
#  'giants': 578,
#  'those': 579,
#  'mighty': 580,
#  'renown': 581,
#  'wickedness': 582,
#  'imagination': 583,
#  'thoughts': 584,
#  'heart': 585,
#  'only': 586,
#  'continually': 587,
#  'repented': 588,
#  'grieved': 589,
#  'destroy': 590,
#  'fowls': 591,
#  'repenteth': 592,
#  'grace': 593,
#  'just': 594,
#  'perfect': 595,
#  'corrupt': 596,
#  'filled': 597,
#  'violence': 598,
#  'looked': 599,
#  'corrupted': 600,
#  'end': 601,
#  'through': 602,
#  'Make': 603,
#  'ark': 604,
#  'gopher': 605,
#  'wood': 606,
#  'rooms': 607,
#  'pitch': 608,
#  'within': 609,
#  'fashion': 610,
#  'length': 611,
#  'cubits': 612,
#  'breadth': 613,
#  'fifty': 614,
#  'height': 615,
#  'A': 616,
#  'window': 617,
#  'cubit': 618,
#  'finish': 619,
#  'side': 620,
#  'lower': 621,
#  'stories': 622,
#  'even': 623,
#  'do': 624,
#  'flood': 625,
#  'establish': 626,
#  'covenant': 627,
#  'sort': 628,
#  'alive': 629,
#  'gather': 630,
#  'according': 631,
#  'Come': 632,
#  'house': 633,
#  'seen': 634,
#  'righteous': 635,
#  'generation': 636,
#  'clean': 637,
#  'by': 638,
#  'sevens': 639,
#  'fema': 640,
#  'beasts': 641,
#  'cause': 642,
#  'nights': 643,
#  'substance': 644,
#  'off': 645,
#  'six': 646,
#  'hundredth': 647,
#  'year': 648,
#  'month': 649,
#  'seventeenth': 650,
#  'fountains': 651,
#  'broken': 652,
#  'windows': 653,
#  'selfsame': 654,
#  'entered': 655,
#  'They': 656,
#  'bird': 657,
#  'h': 658,
#  'shut': 659,
#  'increased': 660,
#  'lift': 661,
#  'prevailed': 662,
#  'exceedingly': 663,
#  'high': 664,
#  'hills': 665,
#  'covered': 666,
#  'Fifteen': 667,
#  'upward': 668,
#  'prevail': 669,
#  'mountains': 670,
#  'm': 671,
#  'All': 672,
#  'destroyed': 673,
#  'things': 674,
#  'remained': 675,
#  'remembered': 676,
#  'wind': 677,
#  'asswaged': 678,
#  'stopped': 679,
#  'restrained': 680,
#  'returned': 681,
#  'abated': 682,
#  'Ararat': 683,
#  'decreased': 684,
#  'until': 685,
#  'tenth': 686,
#  'tops': 687,
#  'ma': 688,
#  'raven': 689,
#  'fro': 690,
#  'dried': 691,
#  'Also': 692,
#  'dove': 693,
#  'no': 694,
#  'rest': 695,
#  'sole': 696,
#  'foot': 697,
#  'pulled': 698,
#  'stayed': 699,
#  'lo': 700,
#  'olive': 701,
#  'leaf': 702,
#  'pluckt': 703,
#  'o': 704,
#  'removed': 705,
#  'covering': 706,
#  'twentieth': 707,
#  'spake': 708,
#  'Go': 709,
#  'Bring': 710,
#  'breed': 711,
#  'Every': 712,
#  'kinds': 713,
#  'altar': 714,
#  'offered': 715,
#  'burnt': 716,
#  'offerings': 717,
#  'smelled': 718,
#  'sweet': 719,
#  'savour': 720,
#  'curse': 721,
#  'youth': 722,
#  'smite': 723,
#  'While': 724,
#  'remaineth': 725,
#  'seedtime': 726,
#  'harvest': 727,
#  'cold': 728,
#  'heat': 729,
#  'summer': 730,
#  'winter': 731,
#  'cease': 732,
#  'fear': 733,
#  'dread': 734,
#  'fishes': 735,
#  'delivered': 736,
#  'liveth': 737,
#  'lives': 738,
#  'require': 739,
#  'Whoso': 740,
#  'sheddeth': 741,
#  'shed': 742,
#  'therein': 743,
#  'cut': 744,
#  'token': 745,
#  'perpetual': 746,
#  'generatio': 747,
#  'bow': 748,
#  'cloud': 749,
#  'clo': 750,
#  'remember': 751,
#  'look': 752,
#  'everlasting': 753,
#  'established': 754,
#  'Japhe': 755,
#  'Canaan': 756,
#  'overspread': 757,
#  'husbandman': 758,
#  'vineyard': 759,
#  'drank': 760,
#  'wine': 761,
#  'drunken': 762,
#  'uncovered': 763,
#  'tent': 764,
#  'nakedness': 765,
#  'brethren': 766,
#  'garment': 767,
#  'laid': 768,
#  'shoulders': 769,
#  'backward': 770,
#  'faces': 771,
#  'awoke': 772,
#  'younger': 773,
#  'Cursed': 774,
#  'servant': 775,
#  'servants': 776,
#  'Blessed': 777,
#  'enlarge': 778,
#  'these': 779,
#  'Gomer': 780,
#  'Magog': 781,
#  'Madai': 782,
#  'Javan': 783,
#  'Tubal': 784,
#  'Meshech': 785,
#  'Tiras': 786,
#  'Ashkenaz': 787,
#  'Riphath': 788,
#  'Togarmah': 789,
#  'Elishah': 790,
#  'Tarshish': 791,
#  'Kittim': 792,
#  'Dodanim': 793,
#  'By': 794,
#  'isles': 795,
#  'Gentiles': 796,
#  'lands': 797,
#  'tongue': 798,
#  'families': 799,
#  'nations': 800,
#  'Cush': 801,
#  'Mizraim': 802,
#  'Phut': 803,
#  'Seba': 804,
#  'Sabtah': 805,
#  'Raamah': 806,
#  'Sabtech': 807,
#  'Sheba': 808,
#  'Dedan': 809,
#  'Nimrod': 810,
#  'He': 811,
#  'hunter': 812,
#  'wherefore': 813,
#  'Even': 814,
#  'kingdom': 815,
#  'Babel': 816,
#  'Erech': 817,
#  'Accad': 818,
#  'Calneh': 819,
#  'Shinar': 820,
#  'Out': 821,
#  'Asshur': 822,
#  'Nineveh': 823,
#  'Rehoboth': 824,
#  'Calah': 825,
#  'Resen': 826,
#  'Ludim': 827,
#  'Anamim': 828,
#  'Lehabim': 829,
#  'Naphtuhim': 830,
#  'Pathrusim': 831,
#  'Casluhim': 832,
#  'Philistim': 833,
#  'Caphtorim': 834,
#  'Sidon': 835,
#  'Heth': 836,
#  'Jebusite': 837,
#  'Amorite': 838,
#  'Girgasite': 839,
#  'Hivite': 840,
#  'Arkite': 841,
#  'Sinite': 842,
#  'Arvadite': 843,
#  'Zemarite': 844,
#  'Hamathite': 845,
#  'afterward': 846,
#  'Canaanites': 847,
#  'spread': 848,
#  'abroad': 849,
#  'border': 850,
#  'comest': 851,
#  'Gerar': 852,
#  'Gaza': 853,
#  'goest': 854,
#  'Sodom': 855,
#  'Gomorrah': 856,
#  'Admah': 857,
#  'Zeboim': 858,
#  'Lasha': 859,
#  'tongues': 860,
#  'countries': 861,
#  'Eber': 862,
#  'elder': 863,
#  'Elam': 864,
#  'Arphaxad': 865,
#  'Lud': 866,
#  'Aram': 867,
#  'Uz': 868,
#  'Hul': 869,
#  'Gether': 870,
#  'Mash': 871,
#  'Salah': 872,
#  'Peleg': 873,
#  'Joktan': 874,
#  'Almodad': 875,
#  'Sheleph': 876,
#  'Hazarmaveth': 877,
#  'Jerah': 878,
#  'Hadoram': 879,
#  'Uzal': 880,
#  'Diklah': 881,
#  'Obal': 882,
#  'Abimael': 883,
#  'Ophir': 884,
#  'Jobab': 885,
#  'dwelling': 886,
#  'Mesha': 887,
#  'Sephar': 888,
#  'mount': 889,
#  'natio': 890,
#  'language': 891,
#  'speech': 892,
#  'journeyed': 893,
#  'plain': 894,
#  'brick': 895,
#  'burn': 896,
#  'thoroughly': 897,
#  'slime': 898,
#  'morter': 899,
#  'build': 900,
#  'tower': 901,
#  'top': 902,
#  'reach': 903,
#  'we': 904,
#  'scattered': 905,
#  'down': 906,
#  'people': 907,
#  'begin': 908,
#  'nothing': 909,
#  'imagined': 910,
#  'confound': 911,
#  'understand': 912,
#  'left': 913,
#  'scatter': 914,
#  'flo': 915,
#  'Reu': 916,
#  'Serug': 917,
#  'Nahor': 918,
#  'Terah': 919,
#  'nineteen': 920,
#  'Abram': 921,
#  'Haran': 922,
#  'Lot': 923,
#  'nativity': 924,
#  'Ur': 925,
#  'Chaldees': 926,
#  'Sarai': 927,
#  'Milcah': 928,
#  'daughter': 929,
#  'Iscah': 930,
#  'barren': 931,
#  'child': 932,
#  'law': 933,
#  'Get': 934,
#  'country': 935,
#  'kindred': 936,
#  'shew': 937,
#  'nation': 938,
#  'bless': 939,
#  'blessi': 940,
#  'curseth': 941,
#  'departed': 942,
#  'spoken': 943,
#  'souls': 944,
#  'passed': 945,
#  'Sichem': 946,
#  'Moreh': 947,
#  'Canaanite': 948,
#  'appeared': 949,
#  'la': 950,
#  'who': 951,
#  'mountain': 952,
#  'Bethel': 953,
#  'pitched': 954,
#  'having': 955,
#  'west': 956,
#  'Hai': 957,
#  'ea': 958,
#  'going': 959,
#  'still': 960,
#  'south': 961,
#  'famine': 962,
#  'Egypt': 963,
#  'sojourn': 964,
#  'grievous': 965,
#  'near': 966,
#  'enter': 967,
#  'Egyptians': 968,
#  'say': 969,
#  'save': 970,
#  'Say': 971,
#  'pray': 972,
#  'beheld': 973,
#  'princes': 974,
#  'Pharaoh': 975,
#  'commended': 976,
#  'Phara': 977,
#  'entreated': 978,
#  'oxen': 979,
#  'asses': 980,
#  'menservants': 981,
#  'maidservants': 982,
#  'camels': 983,
#  'plagued': 984,
#  'plagues': 985,
#  'didst': 986,
#  'tell': 987,
#  'saidst': 988,
#  'She': 989,
#  'might': 990,
#  'therefore': 991,
#  'away': 992,
#  'rich': 993,
#  'silver': 994,
#  'journeys': 995,
#  'been': 996,
#  'fir': 997,
#  'flocks': 998,
#  'herds': 999,
#  ...}

# %%
import time

# %%
a = []
for sentence in gen.sents():
    sen = []
    for word in sentence:
        if word.isalpha():
            sen.append((word,pos_tag([word])[0][1]))
    a.append(sen)

# %%
trainer = nltk.tag.hmm.HiddenMarkovModelTrainer()
start = time.clock()
trainer.train_unsupervised(unlabeled_sequences=a , model = model, max_iterations = 1)
print (time.clock() - start)
# Out:
# /home/vidur/anaconda3/lib/python3.6/site-packages/nltk/tag/hmm.py:1156: RuntimeWarning: invalid value encountered in subtract
#   return np.log2(np.sum(2 ** (arr - max_))) + max_
# /home/vidur/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-f2cc97bc5859> in <module>()
#       1 trainer = nltk.tag.hmm.HiddenMarkovModelTrainer()
#       2 start = time.clock()
# ----> 3 trainer.train_unsupervised(unlabeled_sequences=a , model = model, max_iterations = 1)
#       4 print (time.clock() - start)
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tag/hmm.py in train_unsupervised(self, unlabeled_sequences, update_outputs, **kwargs)
#    1034                     seq_B_numer,
#    1035                     seq_B_denom,
# -> 1036                 ) = self._baum_welch_step(sequence, model, symbol_numbers)
#    1037
#    1038                 # add these sums to the global A and B values
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tag/hmm.py in _baum_welch_step(self, sequence, model, symbol_to_number)
#     922             if t < T - 1:
#     923                 next_symbol = sequence[t + 1][_TEXT]  # not found? FIXME
# --> 924             xi = symbol_to_number[symbol]
#     925
#     926             next_outputs_logprob = model._outputs_vector(next_symbol)
#
# KeyError: '.'

# %%
from hmm_log import *
model2 = hmm(len(states))
model2.custom(initial,transition,emission.T)
start = time.clock()
model2.fitMultiple(obs_blake,lens)
time.clock() - start
# Out:
# /home/vidur/Desktop/ABT/comparison/logP.py:156: RuntimeWarning: divide by zero encountered in log10
#   ea = a.exp + np.log10(a.mant)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-bb0974f3b353> in <module>()
#       3 model2 = hmm(len(states))
#       4 model2.custom(initial,transition,emission.T)
# ----> 5 model2.fitMultiple(obs_blake,lens)
#
# ~/Desktop/ABT/comparison/hmm_log.py in fitMultiple(self, Obs, Ls)
#     319             #print 'starting alk,bek:', olen, Ok
#     320             alphak.append(self.forwardSL(Ok))
# --> 321             betak.append(self.backwardSL(Ok))
#     322             Pk.append(self.POlambda(Ok))
#     323             obsl.append(Ok)
#
# ~/Desktop/ABT/comparison/hmm_log.py in backwardSL(self, Y)
#     123         N = self.N
#     124         logA =  logPm(self.transmat_)
# --> 125         logB =  logPm(self.emissionprob_)
#     126         #initialization                                 (24)
#     127         beta = logPm(np.ones((T,N)))
#
# ~/Desktop/ABT/comparison/logP_matrix.py in __init__(self, Pm)
#      34                     p = Pm[r,c]
#      35                     assert isinstance(p,numbers.Number), fs
# ---> 36                     self.m[r,c] = logP(p)
#      37         if len(s) == 3:
#      38             tc,rc,cc = np.shape(Pm)
#
# ~/Desktop/ABT/comparison/logP.py in __float__(self)
#      56     def __float__(self):
#      57         #return 5
# ---> 58         return self.test_val()
#      59
#      60     def __str__(self):
#
# ~/Desktop/ABT/comparison/logP.py in test_val(self)
#      69
#      70     def test_val(self):  # return a float64 for testing
# ---> 71         return np.float64(self.mant*10.00**self.exp)
#      72
#      73
#
# KeyboardInterrupt:

# %%
len(states
   )
# Out:
# 35
